# %%
import graphlab as gl
import matplotlib as mpl
repins_tr = gl.SFrame.read_csv('repins.train.csv', delimiter='|')
repins_te = gl.SFrame.read_csv('repins.test.csv', delimiter='|')
repins_sp = gl.SFrame.read_csv('repins.test.csv', delimiter='|')
# Out:
# PROGRESS: Finished parsing file /home/volodya/Downloads/repins.train.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.04339 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,int,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /home/volodya/Downloads/repins.train.csv
# PROGRESS: Parsing completed. Parsed 54251 lines in 0.044566 secs.
# PROGRESS: Finished parsing file /home/volodya/Downloads/repins.test.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.027532 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,int,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /home/volodya/Downloads/repins.test.csv
# PROGRESS: Parsing completed. Parsed 27196 lines in 0.03176 secs.
# PROGRESS: Finished parsing file /home/volodya/Downloads/repins.test.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.038266 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,int,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /home/volodya/Downloads/repins.test.csv
# PROGRESS: Parsing completed. Parsed 27196 lines in 0.034213 secs.

# %%
repins_tr
# Out:
# Columns:
# 	user_id	int
# 	item_id	int
# 	category	int
# 	anonymized_board_id	int
#
# Rows: 54251
#
# Data:
# +---------+---------+----------+---------------------+
# | user_id | item_id | category | anonymized_board_id |
# +---------+---------+----------+---------------------+
# |    35   |    65   |    20    |          66         |
# |    39   |    72   |    3     |          73         |
# |    42   |    79   |    25    |          80         |
# |    46   |    84   |    11    |          85         |
# |    50   |    92   |    0     |          94         |
# |    71   |   123   |    25    |         125         |
# |    74   |    72   |    3     |         130         |
# |    81   |   142   |    26    |         145         |
# |    82   |   145   |    29    |         148         |
# |    86   |   150   |    0     |         153         |
# +---------+---------+----------+---------------------+
# [54251 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
repins_te
# Out:
# Columns:
# 	user_id	int
# 	item_id	int
# 	category	int
# 	anonymized_board_id	int
#
# Rows: 27196
#
# Data:
# +---------+---------+----------+---------------------+
# | user_id | item_id | category | anonymized_board_id |
# +---------+---------+----------+---------------------+
# |    8    |    15   |    14    |          15         |
# |    9    |    19   |    1     |          19         |
# |    14   |    29   |    10    |          29         |
# |    64   |   116   |    11    |         118         |
# |    71   |   125   |    29    |         127         |
# |    83   |   147   |    0     |         150         |
# |    94   |   163   |    3     |         167         |
# |    95   |   169   |    20    |         173         |
# |   127   |   211   |    2     |         215         |
# |   136   |   223   |    25    |         227         |
# +---------+---------+----------+---------------------+
# [27196 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
repins.column_names()
# Out:
# ['8', '15', '14', '15.1']

# %%
del repins_tr["category"]
del repins_tr["anonymized_board_id"]
del repins_te["category"]
del repins_te["anonymized_board_id"]
repins_tr
# Out:
# Columns:
# 	user_id	int
# 	item_id	int
#
# Rows: 54251
#
# Data:
# +---------+---------+
# | user_id | item_id |
# +---------+---------+
# |    35   |    65   |
# |    39   |    72   |
# |    42   |    79   |
# |    46   |    84   |
# |    50   |    92   |
# |    71   |   123   |
# |    74   |    72   |
# |    81   |   142   |
# |    82   |   145   |
# |    86   |   150   |
# +---------+---------+
# [54251 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
e = gl.recommender.create(repins_sp,
                                user_id='user_id',
                                item_id='item_id')
recs = e.recommend()
# Out:
# PROGRESS: Recsys training: model = item_similarity
# PROGRESS: Warning: Ignoring columns category, anonymized_board_id;
# PROGRESS:     To use one of these as a target column, set target = <column_name>
# PROGRESS:     and use a method that allows the use of a target.
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 27196 observations with 21179 users and 12740 items.
# PROGRESS:     Data prepared in: 0.042343s
# PROGRESS: Computing item similarity statistics:
# PROGRESS: Computing most similar items for 12740 items:
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | Number of items | Elapsed Time    |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | 1000            | 1.22846         |
# PROGRESS: | 2000            | 1.28571         |
# PROGRESS: | 3000            | 1.34008         |
# PROGRESS: | 4000            | 1.38855         |
# PROGRESS: | 5000            | 1.42925         |
# PROGRESS: | 6000            | 1.47679         |
# PROGRESS: | 7000            | 1.53971         |
# PROGRESS: | 8000            | 1.59593         |
# PROGRESS: | 9000            | 1.7221          |
# PROGRESS: | 10000           | 1.88469         |
# PROGRESS: | 11000           | 2.03068         |
# PROGRESS: | 12000           | 2.16806         |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: Finished training in 2.51967s
# PROGRESS: recommendations finished on 1000/21179 queries. users per second: 1380.36
# PROGRESS: recommendations finished on 2000/21179 queries. users per second: 1413.66
# PROGRESS: recommendations finished on 3000/21179 queries. users per second: 1432.15
# PROGRESS: recommendations finished on 4000/21179 queries. users per second: 1441.88
# PROGRESS: recommendations finished on 5000/21179 queries. users per second: 1450.91
# PROGRESS: recommendations finished on 6000/21179 queries. users per second: 1453.67
# PROGRESS: recommendations finished on 7000/21179 queries. users per second: 1454.43
# PROGRESS: recommendations finished on 8000/21179 queries. users per second: 1455.19
# PROGRESS: recommendations finished on 9000/21179 queries. users per second: 1456.1
# PROGRESS: recommendations finished on 10000/21179 queries. users per second: 1455.23
# PROGRESS: recommendations finished on 11000/21179 queries. users per second: 1454.49
# PROGRESS: recommendations finished on 12000/21179 queries. users per second: 1454.72
# PROGRESS: recommendations finished on 13000/21179 queries. users per second: 1454.36
# PROGRESS: recommendations finished on 14000/21179 queries. users per second: 1454.02
# PROGRESS: recommendations finished on 15000/21179 queries. users per second: 1453.9
# PROGRESS: recommendations finished on 16000/21179 queries. users per second: 1452.31
# PROGRESS: recommendations finished on 17000/21179 queries. users per second: 1454.19
# PROGRESS: recommendations finished on 18000/21179 queries. users per second: 1459.68
# PROGRESS: recommendations finished on 19000/21179 queries. users per second: 1472.41
# PROGRESS: recommendations finished on 20000/21179 queries. users per second: 1490.19
# PROGRESS: recommendations finished on 21000/21179 queries. users per second: 1499.16

# %%
m = gl.recommender.create(repins_te,
                                user_id='user_id',
                                item_id='item_id')
recs = m.recommend()
# Out:
# PROGRESS: Recsys training: model = item_similarity
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 27196 observations with 21179 users and 12740 items.
# PROGRESS:     Data prepared in: 0.050866s
# PROGRESS: Computing item similarity statistics:
# PROGRESS: Computing most similar items for 12740 items:
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | Number of items | Elapsed Time    |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | 1000            | 1.42314         |
# PROGRESS: | 2000            | 1.48034         |
# PROGRESS: | 3000            | 1.53375         |
# PROGRESS: | 4000            | 1.58279         |
# PROGRESS: | 5000            | 1.63631         |
# PROGRESS: | 6000            | 1.67172         |
# PROGRESS: | 7000            | 1.73348         |
# PROGRESS: | 8000            | 1.79223         |
# PROGRESS: | 9000            | 1.88219         |
# PROGRESS: | 10000           | 2.03209         |
# PROGRESS: | 11000           | 2.17463         |
# PROGRESS: | 12000           | 2.30743         |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: Finished training in 2.65036s
# PROGRESS: recommendations finished on 1000/21179 queries. users per second: 1412.37
# PROGRESS: recommendations finished on 2000/21179 queries. users per second: 1409.86
# PROGRESS: recommendations finished on 3000/21179 queries. users per second: 1410.07
# PROGRESS: recommendations finished on 4000/21179 queries. users per second: 1410.18
# PROGRESS: recommendations finished on 5000/21179 queries. users per second: 1408.05
# PROGRESS: recommendations finished on 6000/21179 queries. users per second: 1407.92
# PROGRESS: recommendations finished on 7000/21179 queries. users per second: 1405.87
# PROGRESS: recommendations finished on 8000/21179 queries. users per second: 1404.48
# PROGRESS: recommendations finished on 9000/21179 queries. users per second: 1402.92
# PROGRESS: recommendations finished on 10000/21179 queries. users per second: 1402.32
# PROGRESS: recommendations finished on 11000/21179 queries. users per second: 1401
# PROGRESS: recommendations finished on 12000/21179 queries. users per second: 1399.98
# PROGRESS: recommendations finished on 13000/21179 queries. users per second: 1398.61
# PROGRESS: recommendations finished on 14000/21179 queries. users per second: 1397.96
# PROGRESS: recommendations finished on 15000/21179 queries. users per second: 1395.89
# PROGRESS: recommendations finished on 16000/21179 queries. users per second: 1392.31
# PROGRESS: recommendations finished on 17000/21179 queries. users per second: 1389.53
# PROGRESS: recommendations finished on 18000/21179 queries. users per second: 1386.63
# PROGRESS: recommendations finished on 19000/21179 queries. users per second: 1382.71
# PROGRESS: recommendations finished on 20000/21179 queries. users per second: 1378.86
# PROGRESS: recommendations finished on 21000/21179 queries. users per second: 1337

# %%
m.recommend([30])
# Out:
# Columns:
# 	anonymized_user_id	int
# 	anonymized_pin_id	int
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +--------------------+-------------------+-------------------+------+
# | anonymized_user_id | anonymized_pin_id |       score       | rank |
# +--------------------+-------------------+-------------------+------+
# |         30         |        7618       |  0.00151927437642 |  1   |
# |         30         |       92182       |  0.00133928571429 |  2   |
# |         30         |       108603      |  0.00129847238543 |  3   |
# |         30         |       74292       |  0.00121951219512 |  4   |
# |         30         |        6448       |  0.00109262219472 |  5   |
# |         30         |       68813       |  0.00103060556465 |  6   |
# |         30         |        6300       |  0.0010118871125  |  7   |
# |         30         |        238        |  0.00100030389514 |  8   |
# |         30         |       34000       | 0.000990740740741 |  9   |
# |         30         |       85484       |  0.00096398046398 |  10  |
# +--------------------+-------------------+-------------------+------+
# [10 rows x 4 columns]

# %%
rec = gl.recommender.item_similarity_recommender.create(repins_tr)
# Out:
# PROGRESS: Recsys training: model = item_similarity
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 54251 observations with 33808 users and 17692 items.
# PROGRESS:     Data prepared in: 0.081767s
# PROGRESS: Computing item similarity statistics:
# PROGRESS: Computing most similar items for 17692 items:
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | Number of items | Elapsed Time    |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | 1000            | 3.55389         |
# PROGRESS: | 2000            | 3.68329         |
# PROGRESS: | 3000            | 3.79181         |
# PROGRESS: | 4000            | 3.90013         |
# PROGRESS: | 5000            | 3.98956         |
# PROGRESS: | 6000            | 4.07257         |
# PROGRESS: | 7000            | 4.21587         |
# PROGRESS: | 8000            | 4.35136         |
# PROGRESS: | 9000            | 4.51673         |
# PROGRESS: | 10000           | 4.65168         |
# PROGRESS: | 11000           | 4.76223         |
# PROGRESS: | 12000           | 5.00345         |
# PROGRESS: | 13000           | 5.34384         |
# PROGRESS: | 14000           | 5.53299         |
# PROGRESS: | 15000           | 5.71196         |
# PROGRESS: | 16000           | 5.87748         |
# PROGRESS: | 17000           | 6.07901         |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: Finished training in 6.73182s

# %%
rec.evaluate_precision_recall(repins_te, cutoffs = [2 , 5, 10, 15, 20, 30, 50, 100])
# Out:
# PROGRESS: recommendations finished on 1000/21179 queries. users per second: 1673.01
# PROGRESS: recommendations finished on 2000/21179 queries. users per second: 1751.48
# PROGRESS: recommendations finished on 3000/21179 queries. users per second: 1771.75
# PROGRESS: recommendations finished on 4000/21179 queries. users per second: 1786.65
# PROGRESS: recommendations finished on 5000/21179 queries. users per second: 1792.67
# PROGRESS: recommendations finished on 6000/21179 queries. users per second: 1789.01
# PROGRESS: recommendations finished on 7000/21179 queries. users per second: 1790.89
# PROGRESS: recommendations finished on 8000/21179 queries. users per second: 1794.92
# PROGRESS: recommendations finished on 9000/21179 queries. users per second: 1783.56
# PROGRESS: recommendations finished on 10000/21179 queries. users per second: 1778.18
# PROGRESS: recommendations finished on 11000/21179 queries. users per second: 1771.99
# PROGRESS: recommendations finished on 12000/21179 queries. users per second: 1775.29
# PROGRESS: recommendations finished on 13000/21179 queries. users per second: 1778.24
# PROGRESS: recommendations finished on 14000/21179 queries. users per second: 1779.28
# PROGRESS: recommendations finished on 15000/21179 queries. users per second: 1781.95
# PROGRESS: recommendations finished on 16000/21179 queries. users per second: 1781.31
# PROGRESS: recommendations finished on 17000/21179 queries. users per second: 1781.84
# PROGRESS: recommendations finished on 18000/21179 queries. users per second: 1782.44
# PROGRESS: recommendations finished on 19000/21179 queries. users per second: 1782.2
# PROGRESS: recommendations finished on 20000/21179 queries. users per second: 1783.36
# PROGRESS: recommendations finished on 21000/21179 queries. users per second: 1785.61
# {'precision_recall_by_user': Columns:
#  	user_id	int
#  	cutoff	int
#  	precision	float
#  	recall	float
#  	count	int
#
#  Rows: 169432
#
#  Data:
#  +---------+--------+-----------+--------+-------+
#  | user_id | cutoff | precision | recall | count |
#  +---------+--------+-----------+--------+-------+
#  |    0    |   2    |    0.0    |  0.0   |   1   |
#  |    0    |   5    |    0.0    |  0.0   |   1   |
#  |    0    |   10   |    0.0    |  0.0   |   1   |
#  |    0    |   15   |    0.0    |  0.0   |   1   |
#  |    0    |   20   |    0.0    |  0.0   |   1   |
#  |    0    |   30   |    0.0    |  0.0   |   1   |
#  |    0    |   50   |    0.0    |  0.0   |   1   |
#  |    0    |  100   |    0.0    |  0.0   |   1   |
#  |    8    |   2    |    0.0    |  0.0   |   1   |
#  |    8    |   5    |    0.0    |  0.0   |   1   |
#  +---------+--------+-----------+--------+-------+
#  [169432 rows x 5 columns]
#  Note: Only the head of the SFrame is printed.
#  You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#  'precision_recall_overall': Columns:
#  	cutoff	int
#  	precision	float
#  	recall	float
#
#  Rows: 8
#
#  Data:
#  +--------+-------------------+------------------+
#  | cutoff |     precision     |      recall      |
#  +--------+-------------------+------------------+
#  |   2    |  0.00151093063884 | 0.00195161874184 |
#  |   5    |  0.00100099154823 | 0.00343264554512 |
#  |   10   | 0.000764908635913 |  0.005212710704  |
#  |   15   | 0.000591781166879 | 0.00615704235327 |
#  |   20   | 0.000583124793427 | 0.00854934919811 |
#  |   30   | 0.000437540330831 | 0.00981632749422 |
#  |   50   | 0.000318239765806 | 0.0121472527818  |
#  |  100   | 0.000229472590774 | 0.0179116105576  |
#  +--------+-------------------+------------------+
#  [8 rows x 3 columns]}

# %%
s = gl.item_similarity_recommender.create(repins_te,
                                user_id='user_id',
                                item_id='item_id',
                                similarity_type='jaccard')
# Out:
# PROGRESS: Recsys training: model = item_similarity
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 27196 observations with 21179 users and 12740 items.
# PROGRESS:     Data prepared in: 0.055021s
# PROGRESS: Computing item similarity statistics:
# PROGRESS: Computing most similar items for 12740 items:
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | Number of items | Elapsed Time    |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | 1000            | 1.02749         |
# PROGRESS: | 2000            | 1.0798          |
# PROGRESS: | 3000            | 1.12563         |
# PROGRESS: | 4000            | 1.16756         |
# PROGRESS: | 5000            | 1.20531         |
# PROGRESS: | 6000            | 1.25            |
# PROGRESS: | 7000            | 1.31892         |
# PROGRESS: | 8000            | 1.37883         |
# PROGRESS: | 9000            | 1.43506         |
# PROGRESS: | 10000           | 1.5071          |
# PROGRESS: | 11000           | 1.61637         |
# PROGRESS: | 12000           | 1.72239         |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: Finished training in 2.07679s

# %%
jrecs = s.recommend()
# Out:
# PROGRESS: recommendations finished on 1000/21179 queries. users per second: 1317.5
# PROGRESS: recommendations finished on 2000/21179 queries. users per second: 1329.2
# PROGRESS: recommendations finished on 3000/21179 queries. users per second: 1335.26
# PROGRESS: recommendations finished on 4000/21179 queries. users per second: 1324.61
# PROGRESS: recommendations finished on 5000/21179 queries. users per second: 1302.82
# PROGRESS: recommendations finished on 6000/21179 queries. users per second: 1289.94
# PROGRESS: recommendations finished on 7000/21179 queries. users per second: 1262.15
# PROGRESS: recommendations finished on 8000/21179 queries. users per second: 1263.11
# PROGRESS: recommendations finished on 9000/21179 queries. users per second: 1267.59
# PROGRESS: recommendations finished on 10000/21179 queries. users per second: 1272.53
# PROGRESS: recommendations finished on 11000/21179 queries. users per second: 1275.97
# PROGRESS: recommendations finished on 12000/21179 queries. users per second: 1279.46
# PROGRESS: recommendations finished on 13000/21179 queries. users per second: 1281.5
# PROGRESS: recommendations finished on 14000/21179 queries. users per second: 1281.81
# PROGRESS: recommendations finished on 15000/21179 queries. users per second: 1278.57
# PROGRESS: recommendations finished on 16000/21179 queries. users per second: 1277.32
# PROGRESS: recommendations finished on 17000/21179 queries. users per second: 1273.58
# PROGRESS: recommendations finished on 18000/21179 queries. users per second: 1274.07
# PROGRESS: recommendations finished on 19000/21179 queries. users per second: 1272.99
# PROGRESS: recommendations finished on 20000/21179 queries. users per second: 1269.37
# PROGRESS: recommendations finished on 21000/21179 queries. users per second: 1254.33

# %%
s.recommend([30])
# Out:
# Columns:
# 	user_id	int
# 	item_id	int
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +---------+---------+-------------------+------+
# | user_id | item_id |       score       | rank |
# +---------+---------+-------------------+------+
# |    30   |  117181 |  0.00153846153846 |  1   |
# |    30   |  49631  |  0.00153846153846 |  2   |
# |    30   |  28460  |  0.00125490196078 |  3   |
# |    30   |  48966  |  0.00108823529412 |  4   |
# |    30   |  26743  |  0.00105263157895 |  5   |
# |    30   |  69430  |  0.00101731601732 |  6   |
# |    30   |  69733  |  0.00101731601732 |  7   |
# |    30   |  163676 | 0.000972850678733 |  8   |
# |    30   |  168819 | 0.000960784313725 |  9   |
# |    30   |   7618  | 0.000952380952381 |  10  |
# +---------+---------+-------------------+------+
# [10 rows x 4 columns]

# %%
from graphlab.toolkits.recommender.util import precision_recall_by_user

# %%
m = gl.recommender.create(repins_tr)
# Out:
# PROGRESS: Recsys training: model = item_similarity
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 54251 observations with 33808 users and 17692 items.
# PROGRESS:     Data prepared in: 0.08334s
# PROGRESS: Computing item similarity statistics:
# PROGRESS: Computing most similar items for 17692 items:
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | Number of items | Elapsed Time    |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: | 1000            | 2.06575         |
# PROGRESS: | 2000            | 2.13288         |
# PROGRESS: | 3000            | 2.19507         |
# PROGRESS: | 4000            | 2.25353         |
# PROGRESS: | 5000            | 2.31067         |
# PROGRESS: | 6000            | 2.36282         |
# PROGRESS: | 7000            | 2.41345         |
# PROGRESS: | 8000            | 2.4599          |
# PROGRESS: | 9000            | 2.51034         |
# PROGRESS: | 10000           | 2.57712         |
# PROGRESS: | 11000           | 2.64394         |
# PROGRESS: | 12000           | 2.7235          |
# PROGRESS: | 13000           | 2.81059         |
# PROGRESS: | 14000           | 2.92314         |
# PROGRESS: | 15000           | 3.02373         |
# PROGRESS: | 16000           | 3.10114         |
# PROGRESS: | 17000           | 3.23363         |
# PROGRESS: +-----------------+-----------------+
# PROGRESS: Finished training in 3.68767s

# %%
recs = m.recommend()
precision_recall_by_user(repins_te, recs, cutoffs=[5, 10, 15, 20, 50, 100])
# Out:
# PROGRESS: recommendations finished on 1000/33808 queries. users per second: 1068.24
# PROGRESS: recommendations finished on 2000/33808 queries. users per second: 1075.89
# PROGRESS: recommendations finished on 3000/33808 queries. users per second: 1077.19
# PROGRESS: recommendations finished on 4000/33808 queries. users per second: 1074.43
# PROGRESS: recommendations finished on 5000/33808 queries. users per second: 1073.16
# PROGRESS: recommendations finished on 6000/33808 queries. users per second: 1070.67
# PROGRESS: recommendations finished on 7000/33808 queries. users per second: 1067.45
# PROGRESS: recommendations finished on 8000/33808 queries. users per second: 1067.49
# PROGRESS: recommendations finished on 9000/33808 queries. users per second: 1064.11
# PROGRESS: recommendations finished on 10000/33808 queries. users per second: 1061.24
# PROGRESS: recommendations finished on 11000/33808 queries. users per second: 1058.97
# PROGRESS: recommendations finished on 12000/33808 queries. users per second: 1056.53
# PROGRESS: recommendations finished on 13000/33808 queries. users per second: 1053.87
# PROGRESS: recommendations finished on 14000/33808 queries. users per second: 1051.64
# PROGRESS: recommendations finished on 15000/33808 queries. users per second: 1050.27
# PROGRESS: recommendations finished on 16000/33808 queries. users per second: 1048.76
# PROGRESS: recommendations finished on 17000/33808 queries. users per second: 1047.5
# PROGRESS: recommendations finished on 18000/33808 queries. users per second: 1046.48
# PROGRESS: recommendations finished on 19000/33808 queries. users per second: 1047.04
# PROGRESS: recommendations finished on 20000/33808 queries. users per second: 1054.82
# PROGRESS: recommendations finished on 21000/33808 queries. users per second: 1061.09
# PROGRESS: recommendations finished on 22000/33808 queries. users per second: 1066.51
# PROGRESS: recommendations finished on 23000/33808 queries. users per second: 1071.77
# PROGRESS: recommendations finished on 24000/33808 queries. users per second: 1075.9
# PROGRESS: recommendations finished on 25000/33808 queries. users per second: 1070.9
# PROGRESS: recommendations finished on 26000/33808 queries. users per second: 1070.06
# PROGRESS: recommendations finished on 27000/33808 queries. users per second: 1069.15
# PROGRESS: recommendations finished on 28000/33808 queries. users per second: 1068.3
# PROGRESS: recommendations finished on 29000/33808 queries. users per second: 1066.57
# PROGRESS: recommendations finished on 30000/33808 queries. users per second: 1065.74
# PROGRESS: recommendations finished on 31000/33808 queries. users per second: 1064.92
# PROGRESS: recommendations finished on 32000/33808 queries. users per second: 1062.65
# PROGRESS: recommendations finished on 33000/33808 queries. users per second: 1053.02
# Columns:
# 	user_id	int
# 	cutoff	int
# 	precision	float
# 	recall	float
# 	count	int
#
# Rows: 42358
#
# Data:
# +---------+--------+-----------+--------+-------+
# | user_id | cutoff | precision | recall | count |
# +---------+--------+-----------+--------+-------+
# |    0    |   5    |    0.0    |  0.0   |   1   |
# |    0    |   5    |    0.0    |  0.0   |   1   |
# |    8    |   5    |    0.0    |  0.0   |   1   |
# |    8    |   5    |    0.0    |  0.0   |   1   |
# |    9    |   5    |    0.0    |  0.0   |   1   |
# |    9    |   5    |    0.0    |  0.0   |   1   |
# |    12   |   5    |    0.0    |  0.0   |   1   |
# |    12   |   5    |    0.0    |  0.0   |   1   |
# |    13   |   5    |    0.0    |  0.0   |   1   |
# |    13   |   5    |    0.0    |  0.0   |   1   |
# +---------+--------+-----------+--------+-------+
# [42358 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
clear_repins = repins_te[clear_repins = repins_te[(repins_te['anonymized_user_id'] == s.recommend([1]) )]&(repins_te['anonymized_pin_id'] == None)]

# %%
precision_recall_by_user(repins_tr, jrecs, cutoffs=[5, 10])
# Out:
# Columns:
# 	user_id	int
# 	cutoff	int
# 	precision	float
# 	recall	float
# 	count	int
#
# Rows: 67616
#
# Data:
# +---------+--------+-----------+--------+-------+
# | user_id | cutoff | precision | recall | count |
# +---------+--------+-----------+--------+-------+
# |    0    |   5    |    0.0    |  0.0   |   3   |
# |    0    |   10   |    0.0    |  0.0   |   3   |
# |    4    |   5    |    0.0    |  0.0   |   1   |
# |    4    |   10   |    0.0    |  0.0   |   1   |
# |    5    |   5    |    0.0    |  0.0   |   1   |
# |    5    |   10   |    0.0    |  0.0   |   1   |
# |    7    |   5    |    0.0    |  0.0   |   2   |
# |    7    |   10   |    0.0    |  0.0   |   2   |
# |    8    |   5    |    0.0    |  0.0   |   2   |
# |    8    |   10   |    0.0    |  0.0   |   2   |
# +---------+--------+-----------+--------+-------+
# [67616 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.
